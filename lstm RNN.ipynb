# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import numpy as np

# %%
data = [[[(i+j)/100] for i in range(6)] for j in range(100)]  #vectors of size 1X1
target = [(i+6)/100 for i in range(100)]

# %%
data = np.array(data, dtype='float')
target = np.array(target, dtype ='float')

# %%
data.shape
# Out:
# (100, 7, 1)

# %%
target.shape
# Out:
# (100,)

# %%
x_train,x_test,y_train,y_test = train_test_split(data,target,test_size = 0.2, random_state = 4)

# %%
x_train.shape
# Out:
# (80, 7, 1)

# %%
#RNN
model = Sequential()

# %%
model.add(LSTM((1),batch_input_shape=(None,None,1), return_sequences=True))
model.add(LSTM((1),return_sequences=False))

# %%
model.compile(optimizer='adam', loss = 'mean_absolute_error',metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_13 (LSTM)               (None, None, 1)           12
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 1)                 12
# ...
# Total params: 24
# Trainable params: 24
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train,epochs=400,validation_data=(x_test,y_test))
# Out:
# Train on 80 samples, validate on 20 samples
# Epoch 1/400
# 80/80 [==============================] - 0s 548us/step - loss: 0.0644 - acc: 0.0125 - val_loss: 0.0444 - val_acc: 0.0000e+00
# Epoch 2/400
# 80/80 [==============================] - 0s 534us/step - loss: 0.0488 - acc: 0.0125 - val_loss: 0.0225 - val_acc: 0.0000e+00
# Epoch 3/400
# 80/80 [==============================] - 0s 499us/step - loss: 0.0272 - acc: 0.0125 - val_loss: 0.0282 - val_acc: 0.0000e+00
# Epoch 4/400
# 80/80 [==============================] - 0s 494us/step - loss: 0.0221 - acc: 0.0125 - val_loss: 0.0451 - val_acc: 0.0000e+00
# Epoch 5/400
# 80/80 [==============================] - 0s 459us/step - loss: 0.0335 - acc: 0.0125 - val_loss: 0.0430 - val_acc: 0.0000e+00
# Epoch 6/400
# 80/80 [==============================] - 0s 423us/step - loss: 0.0265 - acc: 0.0125 - val_loss: 0.0281 - val_acc: 0.0000e+00
# Epoch 7/400
# ...

# %%
results = model.predict(x_test)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(range(20), results,c='r')
plt.scatter(range(20),y_test, c ='g')

# %%
plt.plot(history.history['loss'])
plt.show()

# %%
#change input size and predict using the same model
data = [[[(i+j)/100] for i in range(7)] for j in range(100)]  #vectors of size 1X1
target = [(i+7)/100 for i in range(100)]

# %%
mean_squared_error(results,y_test)
# Out:
# 0.000877096008572823

# %%
y_test*100
# Out:
# array([ 27.,  17., 103.,  23.,  70.,  31.,  60., 104.,  48.,  54.,  50.,
#          9., 102.,  33.,  20.,  44.,  21.,  36.,  42.,  61.])

# %%
results*100
# Out:
# array([[26.58143 ],
#        [18.607294],
#        [96.05171 ],
#        [23.216827],
#        [71.13965 ],
#        [30.169392],
#        [60.552036],
#        [96.228935],
#        [47.428764],
#        [53.98252 ],
#        [49.60229 ],
#        [13.283912],
#        [95.866905],
#        [32.042564],
#        [20.845709],
#        [43.14181 ],
#        [21.621387],
#        [34.944298],
#        [41.038532],
#        [61.637943]], dtype=float32)
